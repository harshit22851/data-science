# %%
import pandas as pd
from sklearn.model_selection import GroupKFold, cross_val_score
from sklearn.linear_model import LinearRegression

# %%
# Load data
data = pd.read_csv('mergedIA.csv')

# %%
data.head(10)
# Out:
#   Participant name  Total Score original  Mouse position X  Mouse position Y  \
# 0  Participant0001                   108       -803.107280        410.467433
# 1  Participant0001                   108       -329.798701        476.396104
# 2  Participant0001                   108       -282.648649        934.743243
# 3  Participant0001                   108       -224.830189       1020.377358
# 4  Participant0001                   108       -150.313433        896.373134
# 5  Participant0001                   108       -150.313433        896.373134
# 6  Participant0001                   108       -402.000000        843.857143
# 7  Participant0001                   108       -402.000000        843.857143
# 8  Participant0001                   108       -803.107280        410.467433
# 9  Participant0001                   108       -329.798701        476.396104
#
#    Unnamed: 0  Recording timestamp  Computer timestamp  Recording duration  \
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


# Define the input and target variables
X = data[['Recording timestamp', 'Gaze point X', 'Gaze point Y','Gaze event duration','Eye movement type index','Fixation point X', 'Fixation point Y']]
y = data['Total Score original']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Test the model on the testing set
predictions = model.predict(X_test)

# Calculate the R^2 score of the model
r_squared = model.score(X_test, y_test)
print("R^2 score:", r_squared)
# Out:
# R^2 score: 0.1290224631217597

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GroupKFold
import numpy as np
from statistics import stdev

# Define the input and target variables
X = data[['Recording timestamp', 'Gaze point X', 'Gaze point Y','Gaze event duration','Eye movement type index','Fixation point X', 'Fixation point Y']]
y = data['Total Score original']
groups = data['Total Score original'] # assume 'Group' is a column that indicates which group each data point belongs to

# Initialize the group k-fold cross-validation iterator
gkf = GroupKFold(n_splits=5)

# Initialize lists to store the scores of each fold
train_scores = []
test_scores = []

# Iterate through each fold
for train_index, test_index in gkf.split(X, y, groups):
    
    # Split the data into training and testing sets
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    
    # Train the linear regression model
    model = LinearRegression()
    model.fit(X_train, y_train)
    
    # Test the model on the training set and store the score
    train_score = model.score(X_train, y_train)
    train_scores.append(train_score)
    
    # Test the model on the testing set and store the score
    test_score = model.score(X_test, y_test)
    test_scores.append(test_score)

# Calculate and print the mean and standard deviation of the scores of each fold
print("Train scores:", train_scores)
print("Mean train score:", sum(train_scores)/len(train_scores))
print("Standard deviation train score:", stdev(train_scores))

print("Test scores:", test_scores)
print("Mean test score:", sum(test_scores)/len(test_scores))
print("Standard deviation test score:", stdev(test_scores))
# Out:
# Train scores: [0.09354404416212014, 0.0753291380257215, 0.18108990278087744, 0.09139558801558623, 0.14652748468363352]
# Mean train score: 0.11757723153358776
# Standard deviation train score: 0.04449705193606433
# Test scores: [-6.2429458723534506, -1.0077061451990548, -0.4021731012298635, -0.05794844046990466, -0.44555638764369476]
# Mean test score: -1.6312659893791939
# Standard deviation test score: 2.6004001095675817

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
data = pd.read_csv('mergedIB.csv')

# Define the input and target variables
X = data[['Recording timestamp', 'Gaze point X', 'Gaze point Y']]
y = data['Total Score original']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train the linear regression model
model = LinearRegression()
model.fit(X_train, y_train)

# Test the model on the testing set
predictions = model.predict(X_test)

# Calculate the R^2 score of the model
r_squared = model.score(X_test, y_test)
print("R^2 score:", r_squared)
# Out:
# R^2 score: 0.05792066746514524
